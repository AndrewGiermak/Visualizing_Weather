# %%
import os
import pandas as pd

# %%
csv = 'weather_df.csv'
tables = pd.read_csv(csv)
tables
# Out:
#      Unnamed: 0   City Name Country  Latitude  Longitude  Temperature  \
# 0             0       arlit      NE     18.74       7.39       104.22
# 1             1     suffolk      US     40.87     -72.80        74.79
# 2             2       vaini      TO    -21.20    -175.20        69.80
# 3             3      albany      US     42.60     -73.97        71.33
# 4             4       kapaa      US     22.08    -159.32        72.09
# ..          ...         ...     ...       ...        ...          ...
# 547         547   normandin      CA     48.83     -72.53        64.40
# 548         548  abu samrah      SY     35.30      37.18        98.82
# 549         549  nelson bay      AU    -32.72     152.15        53.82
# 550         550    la palma      US     33.85    -118.05        67.95
# 551         551        ruwi      OM     23.60      58.55        91.40
#
#      Humidity  Cloudiness  Winds
# 0          18          53   9.19
# 1          64           1  12.75
# ...

# %%
type(tables)
# Out:
# pandas.core.frame.DataFrame

# %%
tables.set_index('City Name', inplace=True)
tables.head()
# Out:
#            Unnamed: 0 Country  Latitude  Longitude  Temperature  Humidity  \
# City Name
# arlit               0      NE     18.74       7.39       104.22        18
# suffolk             1      US     40.87     -72.80        74.79        64
# vaini               2      TO    -21.20    -175.20        69.80        77
# albany              3      US     42.60     -73.97        71.33        64
# kapaa               4      US     22.08    -159.32        72.09        83
#
#            Cloudiness  Winds
# City Name
# arlit              53   9.19
# suffolk             1  12.75
# vaini              75  10.29
# albany             40   8.05
# kapaa              40  14.99

# %%
html_table = tables.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>Country</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Temperature</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Winds</th>\n    </tr>\n    <tr>\n      <th>City Name</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>arlit</th>\n      <td>0</td>\n      <td>NE</td>\n      <td>18.74</td>\n      <td>7.39</td>\n      <td>104.22</td>\n      <td>18</td>\n      <td>53</td>\n      <td>9.19</td>\n    </tr>\n    <tr>\n      <th>suffolk</th>\n      <td>1</td>\n      <td>US</td>\n      <td>40.87</td>\n      <td>-72.80</td>\n      <td>74.79</td>\n      <td>64</td>\n      <td>1</td>\n      <td>12.75</td>\n    </tr>\n    <tr>\n      <th>vaini</th>\n      <td>2</td>\n      <td>
# ...

# %%
html_table.replace('\n', '')
